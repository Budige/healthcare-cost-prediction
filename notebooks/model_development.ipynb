# %% [markdown]
# # Healthcare Cost Prediction Model
# **Goal:** Build ensemble model to predict patient healthcare costs
# **Data:** CMS Medicare sample data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
import shap

# TODO: add more visualization libraries

# %%
# Load data
df = pd.read_csv('../data/sample/patient_sample.csv')
print(f"Loaded {len(df)} records")

# FIXME: Need to handle missing BMI values

# %%
# Feature engineering
# Tried polynomial features but didn't improve R2
# df['age_squared'] = df['age'] ** 2  # commented out - didn't help

# Comorbidity score seems to be key feature
df['comorbidity_score'] = df['diabetes'] + df['heart_disease']

# %% [markdown]
# ## Model Training
# Testing XGBoost vs Random Forest

# %%
# Train XGBoost
# NOTE: These parameters were tuned using GridSearch (see separate notebook)
xgb = XGBRegressor(n_estimators=500, max_depth=8, learning_rate=0.05)

# TODO: Add cross-validation scores
